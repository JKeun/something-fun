# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

df = pd.DataFrame(columns=["company", "description", "link"])

# page is from 1 to 1024
for page in range(30):
    response = requests.get("https://www.rocketpunch.com/companies?page={}".format(page))
    
    dom = BeautifulSoup(response.content, "html.parser")
    elements = dom.select("#company-list div.content")
    
    for element in elements:
        company_name = element.select_one('strong').string
        link = element.select_one('a').attrs.get('href')
        description = element.select_one('div.description').string
        
        df.loc[len(df)] = [company_name, description, link]
df
# Out:
#                                         company                                                                                 description                                               link
# 0                   디스커버리오브모션 주식회사   자유롭게 변형 가능한 VR(가상현실) 카메라 상용화                                                                 /companies/discoveryofmotion
# 1                           주식회사 케이파머스        실시간 생산정보기반 농업 O2O플랫폼,K파머스                                                                          /companies/kfarmers
# 2                                        엔타로                                                                                                                            /companies/entaro-3
# 3                               위버스 (WEAVUS)  위버스(WEAVUS)는 사람과 사람을 이어 더 멋진 세상을 만들어나갑니다. ......                                               /companies/weavuscorp
# 4                                    어반베이스  공간정보와 가상현실을 융합한 플랫폼을 서비스하는 회사입니다. ......                                                      /companies/urbanbase
# 5                                      당근마켓  우리동네 중고 직거래 앱인 '당근마켓'을 만드는 회사입니다. ......                                                            /companies/daangn
# 6                                        코나드                                                                                                                               /companies/conad
# 7       Samsung Research Institute in Bangalore                                                                                              /companies/samsung-research-institute-in-banga...
# 8                                      한경닷컴                                                                                                                    /companies/hangyeongdaskeom
# 9                                    스켈터랩스      AI 기술 중심의 글로벌 테크 스타트업 스튜디오                                                                       /companies/skelterlabs
# 10                                       래드손                          Full Stack Audio Company                                                                           /companies/radsone
# 11                                       오쉐어                                제주도 몸만 오쉐어                                                                            /companies/oshare
# 12                          CDNetworks Co.,Ltd.                                                                                                                   /companies/cdnetworks-co-ltd
# 13                                   애드마이어                     세상을 바꾸는 인터렉티브 광고                                                                            /companies/admire
# 14                                     크라우디       세상을 바꿀 당신의 아이디어가 시작되는 그곳                                                                   /companies/doablerplatform
# 15                                     미트박스                          B2B 축산물 직거래 플랫폼                                                                           /companies/meatbox
# 16                                       브랜디                                  패션커머스플랫폼                                                                            /companies/brandi
# 17                                 아이스라이트  대한민국 No.1 정통 판타지 스포츠 게임, 판타지볼 개발 및 운영 ......                                                       /companies/icelight
# 18                                       어니컴                                                                                                                          /companies/eonikeom-2
# 19                                   큐씨디정보                                                                                                                     /companies/kyussidijeongbo
# 20                                        319km                                          스타트업                                                                             /companies/319km
# 21                           WK Marketing Group                                                                                                                  /companies/wk-marketing-group
# 22                                      동원F&B  참치캔, 조미김, 냉동식품, 가공밥 등을 생산하는 식품업체 ......                                                         /companies/dongwon-f-b
# 23                                       탠버린  예술과 ICT 융합을 통한 새로운 가치를 만드는 전문가 그룹입니다. ......                                                    /companies/tanberine
# 24                                     리트래블  여행 경험의 디테일을 쉽고 리치하게 공유할 수 있는 리뷰 커머스 앱 ......                                                    /companies/retravl
# 25                               위드이노베이션    대한민국 숙박020 시장의 NO.1  ㈜위드이노베이션                                                                           /companies/withweb
# 26                                       에디켓                    실시간 영문 교정 서비스 플랫폼                                                                            /companies/ediket
# 27                                     펫메모리  반려동물 피규어,유골분 팬던트,펫 모발 목걸이,반려동물 팬던트 ......                                                      /companies/petmemory
# 28                                       barter  바터-아트바터,기업바터corporate barter,인터넷물물교환, 빈방, 티켓, ...                                                      /companies/barter
# 29                                   프린트가이  토판타,실리콘몰드주문제작업체,주문형실리콘몰드,주문형석고방향제,주문형석고방향제틀,주문...                                /companies/printguy
# ..                                          ...                                                                                         ...                                                ...
# 545                                아이디어큐브     블록 소프트웨어를 활용한 공간 학습, 코딩 교육                                                                          /companies/ideacube
# 546                                     Additor  Get your or your team's knowledge base visuali...                                                                          /companies/additor
# 547                                        바인                                                --                                                                              /companies/took
# 548                                    팀부스터  '회사'를 위해서보단 '나'자신을 위해 스스로 일하는 인재를 모십니다. ......                                              /companies/teambooster
# 549                                베이비프렌즈  우리는 엄마에 마음을 이해하는 것으로 부터 시작합니다. ......                                                           /companies/babyfriends
# 550               Tokyo Design Cop(Tokyo Flash)                                                                                                      /companies/tokyo-design-cop-tokyo-flash-1
# 551                                    오늘하루                     O2O 소셜데이팅 서비스 입니다.                                                                           /companies/onlharu
# 552                              바른생활사람들                                                                                                          /companies/bareunsaenghwalsaramdeul-1
# 553                                        BinD                    상품 경험 기반의 콘텐츠 플랫폼                                                                        /companies/bombindorm
# 554                              디자인사우르스  디자인사우르스는 스타트업/소규모창업 디자인인큐베이팅회사입니다. ......                                 /companies/rightbrothersdesigncompany
# 555  Floating Island convention(FIC)/Sposabella                                                                                              /companies/floating-island-convention-fic-spos...
# 556                Tokyo Design Cop(Tokyo Flash                                                                                                        /companies/tokyo-design-cop-tokyo-flash
# 557                       Hotel New Otani Tokyo                                                                                                               /companies/hotel-new-otani-tokyo
# 558                                Market Kurly                                                                                                                        /companies/market-kurly
# 559                                    오피지지          Connect with all gamers and eSports fans                                                                              /companies/opgg
# 560                                      이어스                   청각보조기구를 본딴 쥬얼리 EARS                                                                              /companies/ears
# 561                                   Retty.Inc                                                                                                                           /companies/retty-inc
# 562                                       Retty                                                                                                                               /companies/retty
# 563                                      메디오                            의료분야 IT서비스 개발                                                                            /companies/mediio
# 564                                      뮤자인                                                                                                                             /companies/myujain
# 565                                  디자인주스  “뭣이 중한디? 사람의 힘!”  믿음, 소망, 사람... 그 중에 제일은 ‘사람’입...                                               /companies/designzoos
# 566                                  보이스로코                                 We connect People                                                                         /companies/voiceloco
# 567                                  우송대학교                                                                                                                    /companies/usongdaehaggyo-1
# 568                                 Woosong Uni                                                                                                                         /companies/woosong-uni
# 569          Roland Berger Strategy Consultants                                                                                                  /companies/roland-berger-strategy-consultants
# 570                               불편한 흥신소  다양한 색깔의 사람들이 모여 문제를 가진 고객을 찾고 세상의 문제를 함께 고민하고 ...                          /companies/uncomfortableagency-1
# 571                                      앞으로                                                                                                                             /companies/front-2
# 572                                        히숲                          예술, 문화 프로그램 중개                                                                            /companies/hysoop
# 573                                  아리앤제이  어떤 예민한 피부에도 잘 맞는 저자극 스킨케어 브랜드, 얼스레시피 ......                                                        /companies/arij
# 574                                        ㅁㅁ                                                                                                                 /companies/uncomfortableagency
#
# [575 rows x 3 columns]
