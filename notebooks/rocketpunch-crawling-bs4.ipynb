# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

df = pd.DataFrame(columns=["company", "link", "description"])

for page in range(50):
    response = requests.get("https://www.rocketpunch.com/companies?page={}".format(page))
    
    dom = BeautifulSoup(response.content, "html.parser")
    elements = dom.select("#company-list div.content")
    
    for element in elements:
        company_name = element.select_one('strong').string
        link = element.select_one('a').attrs.get('href')
        description = element.select_one('div.description').string
        
        df.loc[len(df)] = [company_name, description, link]
df
# Out:
#                         company                                                                                   link                              description
# 0                   TP Partners               WE CONNECT PEOPLE AND OPPORTUNITIES                                                         /companies/tppartners
# 1                  국제무용협회                                                                                                  /companies/gugjemuyonghyeobhoe
# 2             M&K PR Consulting                                                                                                    /companies/m-k-pr-consulting
# 3                  아이디디자인                                   본질을 표현하다                                                           /companies/iddesign
# 4                            KT                                                                                                                /companies/kt-85
# 5                      삼성전자                                                                                                    /companies/samseongjeonja-43
# 6                      Cicerone                                                                                                             /companies/cicerone
# 7                    라이징팝스     작지만 큰그림을 그리고자 하는 에이전시입니다.                                                         /companies/risingpops
# 8                  ZTC Solution                                                                                                         /companies/ztc-solution
# 9                      올드문래                                                                                                          /companies/oldeumunrae
# 10                   네오플라이  스타트업과 한 배를 탄 마음으로, 진심을 다해 돕는 판교의 엑셀러레이터 ......                                  /companies/neoply
# 11                       AhnLab                                                                                                             /companies/ahnlab-2
# 12                        SECUI                                                                                                                /companies/secui
# 13   저자취해요(어른아이미디어)                                                                                         /companies/jeojacwihaeyo-eoreunaimidieo
# 14                   오피엠에스                                                                                                          /companies/opiemeseu-1
# 15                     CJ Media                                                                                                             /companies/cj-media
# 16                       HS애드                                                                                                              /companies/hsaedeu
# 17                  Mogloogames                                                                                                          /companies/mogloogames
# 18                         일벗        스타와 팬들의 소통 전문 플랫폼을 만듭니다.                                                              /companies/ilbut
# 19                   디엘비에스  미국에 디자인과 개발 서비스를 납품하는 스타트업 입니다 ......                                                  /companies/dlbs
# 20                   아이오로라   키오스크중점 사업 (희망,기부,스타포토) 키오스크                                                            /companies/iaurora
# 21                       POSNET                               IT solution Company                                                             /companies/posnet
# 22                     딥퀘스트       인간과 동행하는 인공 지능 기술을 추구합니다                                                          /companies/deepquest
# 23                   이파피루스         이파피루스는 리얼 페이퍼리스를 추구합니다                                                           /companies/epapyrus
# 24               브레이브모바일  숨은 고수를 찾아주는 서비스 '숨고'를 서비스 하고 있습니다. ......                                       /companies/bravemobile
# 25               월드비전코리아                                                                                                   /companies/weoldeubijeonkoria
# 26                    (주)B.U.C                   취약계층을 위한 결혼식 소셜벤처                                                           /companies/ju-b-u-c
# 27                 스마트포스팅  자체 개발한 모바일 마케팅 앱 광고 플랫폼 스마트포스팅을 운영하는 애드테크 기업입니...                  /companies/smartposting
# 28                         뷰틱  뷰틱, 세상을 보여주다 | VUTIC, Show the World - 실감미디어, ...                                               /companies/vutic
# 29                    하우스142   Art 문화와 대중과의 연결고리를 만들어 가는 기업                                                           /companies/house142
# ..                          ...                                                ...                                                                          ...
# 945                      ZIMZOM  한국 최초의 발렛 스토리지 서비스와 여행짐 딜리버리 서비스를 하는 연구소입니다. ....                          /companies/zimzom
# 946                     LEEHAUS                                                                                                              /companies/leehaus
# 947                    리하우스                                                                                                             /companies/rihauseu
# 948             보비어스 코리아                 레스토랑 온라인 주문 및 물류 배송                                                     /companies/vovioskoreainc
# 949                        루루                                                                                                                 /companies/ruru
# 950                씨씨파트너스                                                                                                    /companies/ssissipateuneoseu
# 951             보비어스 코리아                                                                                                      /companies/bobieoseu-koria
# 952                        하비  재능공유를 기반으로하는 O2O 플랫폼 기반 기업입니다. ......                                                   /companies/harbby
# 953              SoftBank Group                                                                                                       /companies/softbank-group
# 954              (주)플레이엔유                                                                                                       /companies/ju-peulreienyu
# 955                  더트라이브  사람들은 어떻게 차를 샀을까? 실거래 정보를 통해 내차를 잘 사는 방법! ......                                   /companies/trive
# 956                에이플러스몰                                                                                                      /companies/eipeulreoseumol
# 957                    시드에듀                                                                                                            /companies/sideuedyu
# 958        (주)코즈엔터테인먼트                                                                                             /companies/ju-kojeuenteoteinmeonteu
# 959              (주)플레이앤유                                                                                                      /companies/ju-peulreiaenyu
# 960                  (주)파시코                                                                                                            /companies/ju-pasiko
# 961              (주)소프트박스                                                                                                    /companies/ju-sopeuteubagseu
# 962                    인포소닉                        모바일 로그인, 결제 서비스                                                       /companies/infosonicinc
# 963                  InnoStream                                                                                                           /companies/innostream
# 964                      UNIWIS                                                                                                               /companies/uniwis
# 965                        UNUS                                                                                                                 /companies/unus
# 966                  세미솔루션                                                                                                       /companies/semisolrusyeon
# 967                    인피노브                                                                                                            /companies/inpinobeu
# 968                  닥터소프트                                                                                                       /companies/dagteosopeuteu
# 969                자이트솔루션                                                                                                     /companies/jaiteusolrusyeon
# 970                    세일창조                                                                                                           /companies/seilcangjo
# 971                      코자자                                                                                                             /companies/kojaja-1
# 972                    마카모아  해외 역직구 소프트웨어 개발, O2O 게임 플랫폼 개발 ......                                                    /companies/macamoa
# 973                         IMQ  새로운 비즈니스 모델 (특허보유)로 더 나은세상을 만드려는 스타트업입니다. ......                                 /companies/imq
# 974                    큐딜리온                                                                                                             /companies/qdillion
#
# [975 rows x 3 columns]
